# %% [markdown]
# ## > Drug Consumption by Age Group

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('../../csv_parser/drug_consumption_cleaned.csv')

data.head()
# Out:
#    ID      Age  Gender                          Education Country  \
# 0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1   2  25 - 34    Male                   Doctorate Degree      UK
# 2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3   4    18-24  Female                     Masters Degree      UK
# 4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity   Nscore   Escore   Oscore   Ascore  ...  \
# 0  Mixed-White/Asian  0.31287 -0.57545 -0.58331 -0.91699  ...
# 1              White -0.67825  1.93886  1.43533  0.76096  ...
# 2              White -0.46725  0.80523 -0.84732 -1.62090  ...
# 3              White -0.14882 -0.80615 -0.01928  0.59042  ...
# 4              White  0.73545 -1.63340 -0.45174 -0.30172  ...
#
#                   Ecstasy      Heroin             Ketamine  \
# 0              Never Used  Never Used           Never Used
# 1      Used in Last Month  Never Used  Used in Last Decade
# ...

# %%
# The dataset has the same number of men and women

data['Gender'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Gender'>

# %%
drugs = ['Alcohol', 'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms', 'Nicotine', 'Semer', 'VSA']
age_ranges = data['Age'].unique()

df = data[["Age"] + drugs]

df.head()
# Out:
#        Age             Alcohol                  Amphet  \
# 0  35 - 44   Used in Last Week     Used in Last Decade
# 1  25 - 34   Used in Last Week     Used in Last Decade
# 2  35 - 44    Used in Last Day              Never Used
# 3    18-24  Used in Last Month              Never Used
# 4  35 - 44  Used in Last Month  Used over a Decade Ago
#
#                      Amyl               Benzos               Caff  \
# 0              Never Used  Used in Last Decade   Used in Last Day
# 1     Used in Last Decade           Never Used   Used in Last Day
# 2              Never Used           Never Used   Used in Last Day
# 3              Never Used    Used in Last Year  Used in Last Week
# 4  Used over a Decade Ago           Never Used   Used in Last Day
#
#               Cannabis                Choc                 Coke       Crack  \
# 0           Never Used   Used in Last Week           Never Used  Never Used
# 1   Used in Last Month    Used in Last Day    Used in Last Year  Never Used
# ...

# %%
def get_drug_consumption_by_age(df: pd.DataFrame, age_range: str = "18-24", drug: str = "Alcohol") -> None:
    """
    Function to display a bar chart showing the which age range consumes the most of a given drug.
    
    Parameters:
    - df: pandas DataFrame containing the dataset
    - age_range: str, age range to filter the dataset by
    - drug: str, drug to display consumption for
    """
    
    if age_range not in age_ranges:
        raise ValueError(f"age_range must be one of {age_ranges}")

    if drug not in drugs:
        raise ValueError(f"drug must be one of {drugs}")
    
    df = df[df['Age'] == age_range]

    df = df[drug].value_counts()

    df.plot(kind='barh', color='skyblue')
    plt.xlabel(f'{age_range} years old')
    plt.xticks(rotation=45)
    plt.ylabel('Count')
    plt.title(f'{drug.capitalize()} Consumption by Age')
    plt.show()

# %%
from random import choice

for _ in range(5):
    get_drug_consumption_by_age(df, age_range=choice(age_ranges), drug=choice(drugs))
