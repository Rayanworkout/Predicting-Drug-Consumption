# %% [markdown]
# ## > Correlation between personality traits and the consumption of each drug

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('../../csv_parser/drug_consumption_cleaned.csv')

df.head()
# Out:
#    ID      Age  Gender                          Education Country  \
# 0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1   2  25 - 34    Male                   Doctorate Degree      UK
# 2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3   4    18-24  Female                     Masters Degree      UK
# 4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity   Nscore   Escore   Oscore   Ascore  ...  \
# 0  Mixed-White/Asian  0.31287 -0.57545 -0.58331 -0.91699  ...
# 1              White -0.67825  1.93886  1.43533  0.76096  ...
# 2              White -0.46725  0.80523 -0.84732 -1.62090  ...
# 3              White -0.14882 -0.80615 -0.01928  0.59042  ...
# 4              White  0.73545 -1.63340 -0.45174 -0.30172  ...
#
#                   Ecstasy      Heroin             Ketamine  \
# 0              Never Used  Never Used           Never Used
# 1      Used in Last Month  Never Used  Used in Last Decade
# ...

# %%
drug_cols = ['Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms', 'Nicotine', 'Semer', 'VSA']

df[drug_cols] = df[drug_cols].replace({
    'Never Used': 0,
    'Used over a Decade Ago': 1,
    'Used in Last Decade': 2,
    'Used in Last Year': 3,
    'Used in Last Month': 4,
    'Used in Last Week': 5,
    'Used in Last Day': 6
})

column_mapping = {
    'Nscore': 'Neuroticism',
    'Escore': 'Extraversion',
    'Oscore': 'Openness',
    'Ascore': 'Agreeableness',
    'Cscore': 'Conscientiousness',
    'Impulsive': 'Impulsiveness',
    'SS': 'Sensation Seeking'
}



corr_matrix = df[list(column_mapping.keys()) + drug_cols].corr().iloc[:7, 7:]

df.head()
# Out:
#    ID      Age  Gender                          Education Country  \
# 0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1   2  25 - 34    Male                   Doctorate Degree      UK
# 2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3   4    18-24  Female                     Masters Degree      UK
# 4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity   Nscore   Escore   Oscore   Ascore  ...  Ecstasy  \
# 0  Mixed-White/Asian  0.31287 -0.57545 -0.58331 -0.91699  ...        0
# 1              White -0.67825  1.93886  1.43533  0.76096  ...        4
# 2              White -0.46725  0.80523 -0.84732 -1.62090  ...        0
# 3              White -0.14882 -0.80615 -0.01928  0.59042  ...        0
# 4              White  0.73545 -1.63340 -0.45174 -0.30172  ...        1
#
#    Heroin  Ketamine Legalh LSD Meth Mushrooms Nicotine Semer VSA
# 0       0         0      0   0    0         0        2     0   0
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Usage d\'une drogue et personnalité')
plt.xticks(ticks=[i+0.5 for i in range(len(drug_cols))], labels=drug_cols, rotation=30)
plt.yticks(ticks=[i+0.5 for i in range(len(column_mapping))], labels=list(column_mapping.values()), rotation=0)
plt.show()
